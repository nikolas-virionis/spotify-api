# %%
from requests import get, post, delete
import pandas as pd
from sensitive import *

# %%
auth = f"Bearer {AUTH_TOKEN}"
headers = {"Accept": "application/json",
           "Content-Type": "application/json", "Authorization": auth}

# %%
artists = {}
songs = []


def get_total_song_count():
    playlist_res = get(
        f'https://api.spotify.com/v1/playlists/{PLAYLIST_ID}', headers=headers)
    return playlist_res.json()["tracks"]["total"]


def add_genres(list, genres):
    for genre in genres:
        if genre not in list:
            list.append(genre)

    return list


def get_song_genres(song):
    genres = []
    song_artists = ""
    try:
        song_artists = song["track"]["artists"]
    except Exception:
        song_artists = song["artists"]

    for artist in song_artists:
        id = artist["id"]
        if id not in artists:
            artist_genres_res = get(
                f'https://api.spotify.com/v1/artists/{id}', headers=headers)
            try:
                artist_genres = artist_genres_res.json()["genres"]
            except Exception:
                print(artist_genres_res.json())
            genres = add_genres(genres, artist_genres)
            artists[artist["name"]] = artist_genres
        else:
            genres = add_genres(genres, artists[id])

    return genres


def song_data(song):
    return song["track"]['id'], song["track"]['name'], song["track"]['popularity'], [artist["name"] for artist in song["track"]["artists"]]

# %%
total_song_count = get_total_song_count()

# %%
all_genres = []
for offset in range(0, total_song_count, 100):
    all_genres_res = get(
        f'https://api.spotify.com/v1/playlists/{PLAYLIST_ID}/tracks?limit=100&offset={offset}', headers=headers)
    for song in all_genres_res.json()["items"]:
        (id, name, popularity, artist), song_genres = song_data(
            song), get_song_genres(song)
        songs.append({"id": id, "name": name, "artists": artist,
                     "popularity": popularity, "genres": song_genres})
        all_genres = add_genres(all_genres, song_genres)

# %%
songs = songs[-total_song_count:]

# %%
playlist = pd.DataFrame(data=songs, columns=[
                        'id', 'name', 'artists', 'popularity', 'genres'])

# %%
playlist
# Out:
#                          id                              name  \
# 0    6Z2pe32hFnUd2x5NgO5KFc  Die For You (feat. Dominic Fike)
# 1    4ZLzoOkj0MPWrTLvooIuaa     Get You The Moon (feat. Snøw)
# 2    4WzhjxvLP95y7AMDy0Atwb                       Out Of Love
# 3    4P1L6AniTDJzANaubzWGYs      I'm Not Enough and I'm Sorry
# 4    3xMTM729pJSwUv55WwWcm2                            change
# ..                      ...                               ...
# 981  6OVpQb3zarqu0vfQav0Wwx            thenineteenseventyfive
# 982  0dOY7HTtl9OhlouW5ToZNC  I'm Leaving, Sorry For Your Loss
# 983  7byGwLkiIzJdHOZKZMS8nd             Something Super Sweet
# 984  5ARrWiDDRDocvURbemcnCy                Cut My Fingers Off
# 985  4AL35ipeLY3R45DhAteP8H                  self destructive
#
#                            artists  popularity  \
# 0    [Justin Bieber, Dominic Fike]          57
# 1                     [Kina, Snøw]          83
# 2                   [Alessia Cara]          77
# 3                   [Teqkoi, Snøw]          69
# 4                       [One Hope]          44
# ..                             ...         ...
# 981                    [push baby]          53
# 982                  [iamnotshane]          49
# 983                  [Rory Webley]          65
# 984               [Ethan Bortnick]          50
# 985                        [Vorsa]          57
#
#                                                 genres
# 0            [canadian pop, pop, alternative pop rock]
# 1                                 [sad lo-fi, sad rap]
# 2    [canadian contemporary r&b, canadian pop, danc...
# 3                    [lo-fi chill, sad lo-fi, sad rap]
# 4                                          [sad lo-fi]
# ..                                                 ...
# 981                                           [uk pop]
# 982                                                 []
# 983                          [alt z, social media pop]
# 984                                                 []
# 985         [emo rap, lo-fi chill, sad lo-fi, sad rap]
#
# [986 rows x 5 columns]

# %%
playlist.to_csv('mid-term-playlist.csv', header=True, index=None)

# %%
all_artists = list(artists.keys())
playlist = pd.read_csv('mid-term-playlist.csv')
playlist
# Out:
#                          id                              name  \
# 0    6Z2pe32hFnUd2x5NgO5KFc  Die For You (feat. Dominic Fike)
# 1    4ZLzoOkj0MPWrTLvooIuaa     Get You The Moon (feat. Snøw)
# 2    4WzhjxvLP95y7AMDy0Atwb                       Out Of Love
# 3    4P1L6AniTDJzANaubzWGYs      I'm Not Enough and I'm Sorry
# 4    3xMTM729pJSwUv55WwWcm2                            change
# ..                      ...                               ...
# 981  6OVpQb3zarqu0vfQav0Wwx            thenineteenseventyfive
# 982  0dOY7HTtl9OhlouW5ToZNC  I'm Leaving, Sorry For Your Loss
# 983  7byGwLkiIzJdHOZKZMS8nd             Something Super Sweet
# 984  5ARrWiDDRDocvURbemcnCy                Cut My Fingers Off
# 985  4AL35ipeLY3R45DhAteP8H                  self destructive
#
#                                artists  popularity  \
# 0    ['Justin Bieber', 'Dominic Fike']          57
# 1                     ['Kina', 'Snøw']          83
# 2                     ['Alessia Cara']          77
# 3                   ['Teqkoi', 'Snøw']          69
# 4                         ['One Hope']          44
# ..                                 ...         ...
# 981                      ['push baby']          53
# 982                    ['iamnotshane']          49
# 983                    ['Rory Webley']          65
# 984                 ['Ethan Bortnick']          50
# 985                          ['Vorsa']          57
#
#                                                 genres
# 0      ['canadian pop', 'pop', 'alternative pop rock']
# 1                             ['sad lo-fi', 'sad rap']
# 2    ['canadian contemporary r&b', 'canadian pop', ...
# 3              ['lo-fi chill', 'sad lo-fi', 'sad rap']
# 4                                        ['sad lo-fi']
# ..                                                 ...
# 981                                         ['uk pop']
# 982                                                 []
# 983                      ['alt z', 'social media pop']
# 984                                                 []
# 985  ['emo rap', 'lo-fi chill', 'sad lo-fi', 'sad r...
#
# [986 rows x 5 columns]

# %%
def genres_indexed(genres):
    indexed = []
    for all_genres_x in all_genres:

        continue_outer = False
        for genre in genres:
            index = all_genres_x == genre
            if index:
                continue_outer = True
                indexed.append(int(True))
                break

        if continue_outer:
            continue

        indexed.append(int(False))

    return indexed


def artists_indexed(artists):
    indexed = []
    for all_artists_x in all_artists:

        continue_outer = False
        for genre in artists:
            index = all_artists_x == genre
            if index:
                continue_outer = True
                indexed.append(int(True))
                break

        if continue_outer:
            continue

        indexed.append(int(False))

    return indexed

# %%
playlist["genres_indexed"] = [genres_indexed(
    eval(playlist["genres"][x])) for x in range(len(playlist["genres"]))]

# %%
playlist.columns = playlist.columns.map(lambda x: x.strip())

# %%
playlist["artists_indexed"] = [artists_indexed(
    eval(playlist["artists"][x])) for x in range(len(playlist["artists"]))]

# %%
playlist.columns
# Out:
# Index(['id', 'name', 'artists', 'popularity', 'genres', 'genres_indexed',
#        'artists_indexed'],
#       dtype='object')

# %% [markdown]
# ## KNN

# %%
def knn_prepared_data(df):
    df = df[['id', 'name', 'genres', 'artists',
             'popularity', 'genres_indexed', 'artists_indexed']]
    list = []
    for index in range(len(df['id'])):
        list.append({'id': df['id'][index], 'name': df['name'][index], 'genres': df['genres'][index], 'artists': df['artists'][index],
                    'popularity': df['popularity'][index], 'genres_indexed': df['genres_indexed'][index], 'artists_indexed': df['artists_indexed'][index]})

    return list

# %%
song_dict = knn_prepared_data(playlist)

# %%
import operator


def getNeighbors(song, K):
    distances = []
    for song_index, song_value in enumerate(song_dict):
        if (song_index != song):
            dist = ComputeDistance(song_dict[song], song_value)
            distances.append((song_index, dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(K):
        neighbors.append(distances[x][0])
    return neighbors

# %%
def list_distance(a, b):
    distance = 0
    for item_a, item_b in list(zip(a, b)):
        distance += 0 if item_a == item_b else 0.2 if (len(a) < 400) else 0.1

    return distance

# %%
def ComputeDistance(a, b):
    genres_distance = list_distance(a['genres_indexed'], b['genres_indexed'])
    artists_distance = list_distance(a['artists_indexed'], b['artists_indexed'])
    popularity_distance = abs(a['popularity'] - b['popularity'])
    
    return genres_distance * 1.3 + artists_distance * 0.2 + popularity_distance * 0.004

# %% [markdown]
# ## Song options
#
# ### Choose one of these to get the 50 closest songs to it

# %%
def get_genres(genres):
    all_genres = genres[0][:]

    for index in range(1, len(genres)):
        for i in range(0, len(all_genres)):
            all_genres[i] = all_genres[i] or genres[index][i]

    return all_genres

    
def get_artists(artists):
    all_artists = artists[0][:]

    for index in range(1, len(artists)):
        for i in range(0, len(all_artists)):
            all_artists[i] = all_artists[i] or artists[index][i]

    return all_artists

# %%
from functools import reduce

top_5 = get('https://api.spotify.com/v1/me/top/tracks?time_range=medium_term&limit=5', headers=headers).json()
top_5_songs = list(filter(lambda song: song['name'] in list(playlist['name']), list(map(lambda song: {'name': song['name'], 'genres': get_song_genres(song), 'artists': list(map(lambda artist: artist['name'],song['artists'])), 'popularity': song['popularity']},top_5['items']))))

# %%
list(map(lambda x: x['name'], top_5['items']))
# Out:
# ['The Story of the Paper Boy',
#  'thor',
#  'A Song For Kaytlyn',
#  'PPL ALWAYS MAKE SHT FKN WORSE',
#  'House of Cards']

# %%
temp_genres = list(reduce(lambda acc, x: acc + list(set(x['genres']) - set(acc)), top_5_songs, []))
temp_artists = list(reduce(lambda acc, x: acc + list(set(x['artists']) - set(acc)), top_5_songs, []))
latest_fav = {'id': "", 'name': "Latest Favorites", 'genres': temp_genres, 'artists': temp_artists}

latest_fav['genres_indexed'] = get_genres(list(map(lambda song: genres_indexed(song['genres']), top_5_songs)))

latest_fav['artists_indexed'] = get_artists(list(map(lambda song: artists_indexed(song['artists']), top_5_songs)))

latest_fav['popularity'] = int(reduce(lambda acc, song: acc + int(song['popularity']), top_5_songs, 0) / len(top_5_songs))

# %%
if len(song_dict) == len(songs):
    song_dict.append(latest_fav)
elif len(song_dict) == len(songs) + 1:
    song_dict.pop()
    song_dict.append(latest_fav)
else:
    raise Exception("error in lists indexes")

# %%
K = 100
index = len(song_dict) - 1
neighbors = getNeighbors(index, K)
print(song_dict[index]['name'], song_dict[index]['artists'], '\n',
      song_dict[index]['genres'], song_dict[index]['popularity'])
for neighbor, index in zip(neighbors, range(1, K + 1)):
    print(
        f'{index}. {song_dict[neighbor]["name"]} \t {song_dict[neighbor]["artists"]} \t {song_dict[neighbor]["genres"]} \t {song_dict[neighbor]["popularity"]}')
# Out:
# Latest Favorites ['Powfu', 'push baby', 'Snøw', 'Skinny Atlas', 'Days to Waste', 'sadeyes', 'Alexander Stewart']
#  ['sad rap', 'uk pop', 'sad lo-fi', 'emo rap', 'lo-fi chill', 'alt z', 'social media pop', 'post-teen pop'] 48
# 1. Remains 	 ['Snøw', 'Skinny Atlas'] 	 ['sad lo-fi', 'sad rap', 'emo rap', 'lo-fi chill'] 	 39
# 2. this is bs. 	 ['Skinny Atlas', 'Laeland', 'Snøw'] 	 ['emo rap', 'lo-fi chill', 'sad lo-fi', 'sad rap'] 	 53
# 3. future diary (feat. Jomie & Skinny Atlas) 	 ['Powfu', 'Jomie', 'Skinny Atlas'] 	 ['sad rap', 'lo-fi chill', 'sad lo-fi', 'emo rap'] 	 53
# 4. A Song For Kaytlyn 	 ['Snøw', 'Skinny Atlas'] 	 ['sad lo-fi', 'sad rap', 'emo rap', 'lo-fi chill'] 	 33
# 5. Evil Queen 	 ['Snøw', 'Skinny Atlas'] 	 ['sad lo-fi', 'sad rap', 'emo rap', 'lo-fi chill'] 	 32
# 6. summer nights 	 ['Skinny Atlas', 'Laeland', 'Snøw'] 	 ['emo rap', 'lo-fi chill', 'sad lo-fi', 'sad rap'] 	 63
# 7. Meant to Be 	 ['Skinny Atlas', 'Snøw', 'Jomie', 'Thomas Reid'] 	 ['emo rap', 'lo-fi chill', 'sad lo-fi', 'sad rap'] 	 59
# 8. Drip 	 ['Snøw', 'Skinny Atlas', 'Jomie'] 	 ['sad lo-fi', 'sad rap', 'emo rap', 'lo-fi chill'] 	 32
# 9. Waiting by the Door 	 ['Thomas Reid', 'Snøw', 'Skinny Atlas'] 	 ['emo rap', 'sad lo-fi', 'sad rap', 'lo-fi chill'] 	 31
# 10. I Fell in Love With You, Now It's Killing Me 	 ['Skinny Atlas', 'Snøw'] 	 ['emo rap', 'lo-fi chill', 'sad lo-fi', 'sad rap'] 	 25
# 11. self destructive 	 ['Vorsa'] 	 ['emo rap', 'lo-fi chill', 'sad lo-fi', 'sad rap'] 	 57
# 12. Walk Away 	 ['SadBoyProlific', 'Aiko', 'Teqkoi'] 	 ['emo rap', 'sad lo-fi', 'sad rap', 'lo-fi chill'] 	 49
# 13. I'm Scared to Fall in Love With You 	 ['Fudasca', 'Aidan', 'Resident'] 	 ['emo rap', 'sad lo-fi', 'sad rap', 'lo-fi chill'] 	 37
# 14. I'm Afraid I'm Gonna Lose You Soon 	 ['Thomas Reid', 'Teqkoi'] 	 ['emo rap', 'sad lo-fi', 'sad rap', 'lo-fi chill'] 	 30
# 15. House of Glass 	 ['Jon Caryl'] 	 ['alt z', 'sad lo-fi', 'sad rap', 'social media pop'] 	 3
# 16. about you 	 ['sadeyes', 'Powfu'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 48
# 17. PPL ALWAYS MAKE SHT FKN WORSE 	 ['sadeyes', 'Days to Waste'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 45
# 18. i can be your home 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 49
# 19. something you hate 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 47
# 20. i deserve better 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 46
# 21. Feel That Again 	 ['Powfu', 'Happily Sad'] 	 ['sad rap', 'emo rap', 'sad lo-fi'] 	 48
# 22. All Without You 	 ['Laeland', 'Snøw'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 48
# 23. you're my everything 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 53
# 24. mess 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 43
# 25. throw it all away (feat. Jomie) 	 ['Powfu', 'Jomie'] 	 ['sad rap', 'lo-fi chill', 'sad lo-fi'] 	 47
# 26. unexpected 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 42
# 27. hi hru 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 42
# 28. Hide in Your Blue Eyes 	 ['Thomas Reid', 'Powfu'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 50
# 29. ily 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 41
# 30. i need you 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 56
# 31. moonlight 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 40
# 32. clip! 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 40
# 33. homescreen 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 38
# 34. pretty sad 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 38
# 35. love is dying. 	 ['Snøw', 'cøzybøy', 'Powfu'] 	 ['sad lo-fi', 'sad rap', 'emo rap'] 	 37
# 36. Compare Myself 	 ['Alexander Stewart'] 	 ['alt z', 'post-teen pop', 'social media pop'] 	 37
# 37. stick n pokes 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 37
# 38. Long Fights, Short Tempers 	 ['Powfu', 'Imfinenow'] 	 ['sad rap', 'lo-fi chill', 'sad lo-fi'] 	 42
# 39. Midnight Thoughts 	 ['SadBoyProlific'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 46
# 40. Sorry I Never Apologized 	 ['Powfu', 'Two:22'] 	 ['sad rap', 'emo rap', 'sad lo-fi'] 	 55
# 41. Mister Mister 	 ['Mishaal'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 50
# 42. Hopeless 	 ['SadBoyProlific'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 51
# 43. don't cry 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 61
# 44. How Miserable Do I Have to Be Before You're Happy 	 ['Beowülf'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 45
# 45. don't cry 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 61
# 46. not alone 	 ['sadeyes', 'Lil Xtra'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 57
# 47. Is It Too Late for Me 	 ['Beowülf'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 53
# 48. Tell Me You Want Me 	 ['Snøw', 'Nuxe'] 	 ['sad lo-fi', 'sad rap', 'lo-fi chill'] 	 38
# 49. House of Cards 	 ['Alexander Stewart'] 	 ['alt z', 'post-teen pop', 'social media pop'] 	 63
# 50. crush 	 ['静的 Static', '50landing'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 48
# 51. you deserve better 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 64
# 52. Blow My Phone Up 	 ['SadBoyProlific', 'Indii G.'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 49
# 53. You're Everything I Need 	 ['Imfinenow', 'yaeow'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 49
# 54. cortisol 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 32
# 55. tendency 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 32
# 56. terrified 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 32
# 57. Not Enough 	 ['SadBoyProlific'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 41
# 58. Scars on My Heart 	 ['Powfu', 'SadBoyProlific'] 	 ['sad rap', 'emo rap', 'sad lo-fi'] 	 60
# 59. If I Lose You 	 ['Kam Michael', 'Rey-Infinite'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 46
# 60. jaded 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 65
# 61. I never wanna lose you 	 ['Teqkoi', 'Snøw'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 60
# 62. I'm inlove but... 	 ['Laeland', 'Snøw'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 60
# 63. Dead and Cold 	 ['SadBoyProlific'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 56
# 64. Alone 	 ['SadBoyProlific', 'Ivri'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 51
# 65. Misconception 	 ['Indii G.', 'SadBoyProlific'] 	 ['sad lo-fi', 'sad rap', 'emo rap'] 	 45
# 66. crystal clear w/ guardin 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 30
# 67. Double Vision 	 ['6host', 'cøzybøy'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 45
# 68. Lost In Between 	 ['yaeow'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 57
# 69. blue 	 ['the bootleg boy', 'artemis orion'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 52
# 70. It Could Always Be Worse 	 ['Seon', 'Lil Xtra'] 	 ['sad lo-fi', 'sad rap', 'emo rap'] 	 43
# 71. Heartbreak 	 ['SadBoyProlific', 'Kuzu Mellow'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 42
# 72. Ryu Kick 	 ['Snøw', 'Teqkoi'] 	 ['sad lo-fi', 'sad rap', 'lo-fi chill'] 	 32
# 73. the reason i'm breathing 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 27
# 74. cryin too much 	 ['sadeyes', 'Koi', 'Lil Xtra'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 37
# 75. moi 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 27
# 76. I'll Be Different 	 ['Zaini', 'vict molina'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 42
# 77. i don't wanna be like u (feat. icy tears) 	 ['sadeyes', 'icy tears'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 31
# 78. Life's a Blur 	 ['Teqkoi', 'Snøw'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 31
# 79. In My Bones 	 ['sadgods', 'SadBoyProlific', 'yung van'] 	 ['emo rap', 'sad rap', 'sad lo-fi'] 	 45
# 80. Bad Habits 	 ['SadBoyProlific', 'Keegan Hayes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 39
# 81. Siphon 	 ['Lil Xtra'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 34
# 82. Scars 	 ['Ondi Vil', 'Mishaal'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 58
# 83. If I Die 	 ['Snøw', 'Josiah MacCartney', 'Criggoh', 'Julia Alexa'] 	 ['sad lo-fi', 'sad rap', 'lo-fi chill'] 	 38
# 84. I'm Not Enough and I'm Sorry 	 ['Teqkoi', 'Snøw'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 69
# 85. You Don't Want Me Anymore 	 ['Snøw', 'Teqkoi'] 	 ['sad lo-fi', 'sad rap', 'lo-fi chill'] 	 71
# 86. The Way I Love You 	 ['yaeow', 'Neptune'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 62
# 87. Bad Idea! 	 ['Unclenathannn', 'Shiloh Dynasty'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 62
# 88. Say Goodbye 	 ['Monty Datta', 'Snøw'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 72
# 89. Scars 	 ['SadBoyProlific', 'Ivri'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 32
# 90. Selfish 	 ['Indii G.', 'SadBoyProlific'] 	 ['sad lo-fi', 'sad rap', 'emo rap'] 	 31
# 91. Pain 	 ['SadBoyProlific', 'Kam Michael'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 29
# 92. Wish I Was Better 	 ['Kina', 'yaeow'] 	 ['sad lo-fi', 'sad rap', 'lo-fi chill'] 	 68
# 93. Can't Love Myself 	 ['Monty Datta', 'Mishaal'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 71
# 94. Please Come Back 	 ['Teqkoi', 'Ondi Vil', 'Thomas Reid', 'Bonjr'] 	 ['lo-fi chill', 'sad lo-fi', 'emo rap', 'sad rap', 'weirdcore'] 	 62
# 95. Lovemark 	 ['Ouse', 'Powfu'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 13
# 96. All Again 	 ['Powfu', 'Nuxe', 'Snøw'] 	 ['sad rap', 'lo-fi chill', 'sad lo-fi'] 	 6
# 97. I Am so Sad... I Am so Very Very Sad 	 ['Alrahim Wright III'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 0
# 98. Just a Little Bit Lonely 	 ['yaeow'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 0
# 99. A Love Letter to You 	 ['SHRK', 'Shiloh Dynasty'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 1
# 100. If You Want to Take My Life 	 ['Vaboh', 'SadBoyProlific'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 0

# %%
def playlist_exists(name):
    request = get('https://api.spotify.com/v1/me/playlists', headers=headers).json()

    playlists = list(map(lambda playlist: (playlist['id'], playlist['name']), request['items']))

    for playlist in playlists:
        if playlist[1] == name:
            return playlist[0]
        
    return False

# %%
import json
playlist_name = 'Recent-ish Favorites'
new_id = ""
playlist_id_found = playlist_exists(playlist_name)
if playlist_id_found:
    new_id = playlist_id_found
    
    playlist_tracks = list(map(lambda track: {'uri': track['track']['uri']}, get(f'https://api.spotify.com/v1/playlists/{new_id}/tracks', headers=headers).json()['items']))

    delete_json = delete(f'https://api.spotify.com/v1/playlists/{new_id}/tracks',  headers=headers, data=json.dumps({"tracks": playlist_tracks})).json()
    print(delete_json)
else:
    data = {"name": playlist_name, "description": f"Songs related to your medium term top 5", "public": False}
    playlist_creation = post(f'https://api.spotify.com/v1/users/{USER_ID}/playlists', headers=headers, data=json.dumps(data))
    new_id = playlist_creation.json()['id']

# %%
song_uris = ''
for neighbor in neighbors:
    if song_dict[neighbor]["id"] != '':
        song_uris += f',spotify:track:{song_dict[neighbor]["id"]}'
    else:
        continue
song_uris = song_uris[1:]
add_songs_req = post(f'https://api.spotify.com/v1/playlists/{new_id}/tracks?uris={song_uris}', headers=headers, data=json.dumps({}))
add_songs_req.json()
# Out:
# {'snapshot_id': 'Myw2NTJmYzc4YzBmYzJiYTQ2NTRlYWZlMmQyYzNjNjM3MTdjOTI1OWNh'}
