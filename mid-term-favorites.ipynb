# %%
from requests import get, post, delete
import pandas as pd
from sensitive import *

# %%
auth = f"Bearer {AUTH_TOKEN}"
headers = {"Accept": "application/json",
           "Content-Type": "application/json", "Authorization": auth}

# %%
artists = {}
songs = []


def get_total_song_count():
    playlist_res = get(
        f'https://api.spotify.com/v1/playlists/{PLAYLIST_ID}', headers=headers)
    return playlist_res.json()["tracks"]["total"]


def add_genres(list, genres):
    for genre in genres:
        if genre not in list:
            list.append(genre)

    return list


def get_song_genres(song):
    genres = []
    song_artists = ""
    try:
        song_artists = song["track"]["artists"]
    except Exception:
        song_artists = song["artists"]

    for artist in song_artists:
        id = artist["id"]
        if id not in artists:
            artist_genres_res = get(
                f'https://api.spotify.com/v1/artists/{id}', headers=headers)
            try:
                artist_genres = artist_genres_res.json()["genres"]
            except Exception:
                print(artist_genres_res.json())
            genres = add_genres(genres, artist_genres)
            artists[artist["name"]] = artist_genres
        else:
            genres = add_genres(genres, artists[id])

    return genres


def song_data(song):
    return song["track"]['id'], song["track"]['name'], song["track"]['popularity'], [artist["name"] for artist in song["track"]["artists"]]

# %%
total_song_count = get_total_song_count()

# %%
all_genres = []
for offset in range(0, total_song_count, 100):
    all_genres_res = get(
        f'https://api.spotify.com/v1/playlists/{PLAYLIST_ID}/tracks?limit=100&offset={offset}', headers=headers)
    for song in all_genres_res.json()["items"]:
        (id, name, popularity, artist), song_genres = song_data(
            song), get_song_genres(song)
        songs.append({"id": id, "name": name, "artists": artist,
                     "popularity": popularity, "genres": song_genres})
        all_genres = add_genres(all_genres, song_genres)

# %%
songs = songs[-total_song_count:]

# %%
playlist = pd.DataFrame(data=songs, columns=[
                        'id', 'name', 'artists', 'popularity', 'genres'])

# %%
playlist
# Out:
#                          id                              name  \
# 0    6Z2pe32hFnUd2x5NgO5KFc  Die For You (feat. Dominic Fike)
# 1    4ZLzoOkj0MPWrTLvooIuaa     Get You The Moon (feat. Snøw)
# 2    4WzhjxvLP95y7AMDy0Atwb                       Out Of Love
# 3    4P1L6AniTDJzANaubzWGYs      I'm Not Enough and I'm Sorry
# 4    6Rf3dWdNQs5LTqFOiavqQr       Canada (feat. Alessia Cara)
# ..                      ...                               ...
# 990  77OXCuJjR83b2mnp0HmYMo                         False Art
# 991  7dMelypWXvdBG5RpRO1RJU                      Purple Candy
# 992  0sEpSjknnHdACZVc7jbmgv                          i miss u
# 993  01WJWHv12F3nWeXGYsmOOs                       Our Way Out
# 994  6wBsMC2U4dbl4JHl1F5z19                     Summer Nights
#
#                            artists  popularity  \
# 0    [Justin Bieber, Dominic Fike]          57
# 1                     [Kina, Snøw]          83
# 2                   [Alessia Cara]          77
# 3                   [Teqkoi, Snøw]          69
# 4             [Lauv, Alessia Cara]          61
# ..                             ...         ...
# 990  [Ben Kessler, Lizzy McAlpine]          53
# 991                  [New Friends]          54
# 992                   [Sammyseven]          43
# 993                 [Nico Collins]          57
# 994      [Ebmusic, bobbyxyz, Kina]          15
#
#                                                 genres
# 0            [canadian pop, pop, alternative pop rock]
# 1                                 [sad lo-fi, sad rap]
# 2    [canadian contemporary r&b, canadian pop, danc...
# 3                    [lo-fi chill, sad lo-fi, sad rap]
# 4    [dance pop, electropop, pop, canadian contempo...
# ..                                                 ...
# 990  [gen z singer-songwriter, alt z, boston folk, ...
# 991                                                 []
# 992                                                 []
# 993                          [alt z, social media pop]
# 994                               [sad lo-fi, sad rap]
#
# [995 rows x 5 columns]

# %%
df = pd.DataFrame(data=[{'artists':artists, 'songs':songs, 'all_genres':songs}], columns=['artists', 'songs', 'all_genres'])

df.to_json('util.json')

# %%
playlist.to_csv('playlist.csv', header=True, index=None)

# %%
df = pd.read_json('util.json')

artists, songs, all_genres = df['artists'][0], df['songs'][0], df['all_genres'][0]

# %%
all_artists = list(artists.keys())
playlist = pd.read_csv('playlist.csv')
playlist
# Out:
#                          id                              name  \
# 0    6Z2pe32hFnUd2x5NgO5KFc  Die For You (feat. Dominic Fike)
# 1    4ZLzoOkj0MPWrTLvooIuaa     Get You The Moon (feat. Snøw)
# 2    4WzhjxvLP95y7AMDy0Atwb                       Out Of Love
# 3    4P1L6AniTDJzANaubzWGYs      I'm Not Enough and I'm Sorry
# 4    6Rf3dWdNQs5LTqFOiavqQr       Canada (feat. Alessia Cara)
# ..                      ...                               ...
# 990  77OXCuJjR83b2mnp0HmYMo                         False Art
# 991  7dMelypWXvdBG5RpRO1RJU                      Purple Candy
# 992  0sEpSjknnHdACZVc7jbmgv                          i miss u
# 993  01WJWHv12F3nWeXGYsmOOs                       Our Way Out
# 994  6wBsMC2U4dbl4JHl1F5z19                     Summer Nights
#
#                                artists  popularity  \
# 0    ['Justin Bieber', 'Dominic Fike']          57
# 1                     ['Kina', 'Snøw']          83
# 2                     ['Alessia Cara']          77
# 3                   ['Teqkoi', 'Snøw']          69
# 4             ['Lauv', 'Alessia Cara']          61
# ..                                 ...         ...
# 990  ['Ben Kessler', 'Lizzy McAlpine']          53
# 991                    ['New Friends']          54
# 992                     ['Sammyseven']          43
# 993                   ['Nico Collins']          57
# 994    ['Ebmusic', 'bobbyxyz', 'Kina']          15
#
#                                                 genres
# 0      ['canadian pop', 'pop', 'alternative pop rock']
# 1                             ['sad lo-fi', 'sad rap']
# 2    ['canadian contemporary r&b', 'canadian pop', ...
# 3              ['lo-fi chill', 'sad lo-fi', 'sad rap']
# 4    ['dance pop', 'electropop', 'pop', 'canadian c...
# ..                                                 ...
# 990  ['gen z singer-songwriter', 'alt z', 'boston f...
# 991                                                 []
# 992                                                 []
# 993                      ['alt z', 'social media pop']
# 994                           ['sad lo-fi', 'sad rap']
#
# [995 rows x 5 columns]

# %%
def genres_indexed(genres):
    indexed = []
    for all_genres_x in all_genres:

        continue_outer = False
        for genre in genres:
            index = all_genres_x == genre
            if index:
                continue_outer = True
                indexed.append(int(True))
                break

        if continue_outer:
            continue

        indexed.append(int(False))

    return indexed


def artists_indexed(artists):
    indexed = []
    for all_artists_x in all_artists:

        continue_outer = False
        for genre in artists:
            index = all_artists_x == genre
            if index:
                continue_outer = True
                indexed.append(int(True))
                break

        if continue_outer:
            continue

        indexed.append(int(False))

    return indexed

# %%
playlist["genres_indexed"] = [genres_indexed(
    eval(playlist["genres"][x])) for x in range(len(playlist["genres"]))]

# %%
playlist.columns = playlist.columns.map(lambda x: x.strip())

# %%
playlist["artists_indexed"] = [artists_indexed(
    eval(playlist["artists"][x])) for x in range(len(playlist["artists"]))]

# %%
playlist.columns
# Out:
# Index(['id', 'name', 'artists', 'popularity', 'genres', 'genres_indexed',
#        'artists_indexed'],
#       dtype='object')

# %% [markdown]
# ## KNN

# %%
def knn_prepared_data(df):
    df = df[['id', 'name', 'genres', 'artists',
             'popularity', 'genres_indexed', 'artists_indexed']]
    list = []
    for index in range(len(df['id'])):
        list.append({'id': df['id'][index], 'name': df['name'][index], 'genres': df['genres'][index], 'artists': df['artists'][index],
                    'popularity': df['popularity'][index], 'genres_indexed': df['genres_indexed'][index], 'artists_indexed': df['artists_indexed'][index]})

    return list

# %%
song_dict = knn_prepared_data(playlist)

# %%
import operator


def getNeighbors(song, K):
    distances = []
    for song_index, song_value in enumerate(song_dict):
        if (song_index != song):
            dist = ComputeDistance(song_dict[song], song_value)
            distances.append((song_index, dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(K):
        neighbors.append(distances[x][0])
    return neighbors

# %%
def list_distance(a, b):
    distance = 0
    for item_a, item_b in list(zip(a, b)):
        distance += 0 if item_a == item_b else 0.2 if (len(a) < 400) else 0.1

    return distance

# %%
def ComputeDistance(a, b):
    genres_distance = list_distance(a['genres_indexed'], b['genres_indexed'])
    artists_distance = list_distance(a['artists_indexed'], b['artists_indexed'])
    popularity_distance = abs(a['popularity'] - b['popularity'])
    
    return genres_distance * 1.3 + artists_distance * 0.2 + popularity_distance * 0.004

# %% [markdown]
# ## Song options
#
# ### Choose one of these to get the 50 closest songs to it

# %%
def get_genres(genres):
    all_genres = genres[0][:]

    for index in range(1, len(genres)):
        for i in range(0, len(all_genres)):
            all_genres[i] = all_genres[i] or genres[index][i]

    return all_genres

    
def get_artists(artists):
    all_artists = artists[0][:]

    for index in range(1, len(artists)):
        for i in range(0, len(all_artists)):
            all_artists[i] = all_artists[i] or artists[index][i]

    return all_artists

# %%
from functools import reduce

top_5 = get('https://api.spotify.com/v1/me/top/tracks?time_range=medium_term&limit=5', headers=headers).json()
top_5_songs = list(filter(lambda song: song['name'] in list(playlist['name']), list(map(lambda song: {'name': song['name'], 'genres': get_song_genres(song), 'artists': list(map(lambda artist: artist['name'],song['artists'])), 'popularity': song['popularity']},top_5['items']))))

# %%
list(map(lambda x: x['name'], top_5['items']))
# Out:
# ['The Story of the Paper Boy',
#  'thor',
#  'A Song For Kaytlyn',
#  'PPL ALWAYS MAKE SHT FKN WORSE',
#  'hi hru']

# %%
temp_genres = list(reduce(lambda acc, x: acc + list(set(x['genres']) - set(acc)), top_5_songs, []))
temp_artists = list(reduce(lambda acc, x: acc + list(set(x['artists']) - set(acc)), top_5_songs, []))
latest_fav = {'id': "", 'name': "Latest Favorites", 'genres': temp_genres, 'artists': temp_artists}

latest_fav['genres_indexed'] = get_genres(list(map(lambda song: genres_indexed(song['genres']), top_5_songs)))

latest_fav['artists_indexed'] = get_artists(list(map(lambda song: artists_indexed(song['artists']), top_5_songs)))

latest_fav['popularity'] = int(reduce(lambda acc, song: acc + int(song['popularity']), top_5_songs, 0) / len(top_5_songs))

# %%
if len(song_dict) == len(songs):
    song_dict.append(latest_fav)
elif len(song_dict) == len(songs) + 1:
    song_dict.pop()
    song_dict.append(latest_fav)
else:
    raise Exception("error in lists indexes")

# %%
K = 100
index = len(song_dict) - 1
neighbors = getNeighbors(index, K)
print(song_dict[index]['name'], song_dict[index]['artists'], '\n',
      song_dict[index]['genres'], song_dict[index]['popularity'])
for neighbor, index in zip(neighbors, range(1, K + 1)):
    print(
        f'{index}. {song_dict[neighbor]["name"]} \t {song_dict[neighbor]["artists"]} \t {song_dict[neighbor]["genres"]} \t {song_dict[neighbor]["popularity"]}')
# Out:
# Latest Favorites ['Powfu', 'push baby', 'Snøw', 'Skinny Atlas', 'sadeyes', 'Days to Waste']
#  ['sad rap', 'uk pop', 'lo-fi chill', 'sad lo-fi', 'emo rap'] 44
# 1. PPL ALWAYS MAKE SHT FKN WORSE 	 ['sadeyes', 'Days to Waste'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 45
# 2. about you 	 ['sadeyes', 'Powfu'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 48
# 3. Remains 	 ['Snøw', 'Skinny Atlas'] 	 ['sad lo-fi', 'sad rap', 'emo rap', 'lo-fi chill'] 	 39
# 4. mess 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 43
# 5. clash of the titans 	 ['Powfu'] 	 ['sad rap'] 	 46
# 6. unexpected 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 42
# 7. moonlight 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 42
# 8. i deserve better 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 46
# 9. hi hru 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 42
# 10. something you hate 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 46
# 11. Her Ocean Eyes 	 ['Powfu'] 	 ['sad rap'] 	 47
# 12. ily 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 41
# 13. Douchebags 	 ['Powfu'] 	 ['sad rap'] 	 41
# 14. I Miss the Old You 	 ['Powfu', 'Rxseboy'] 	 ['sad rap', 'aesthetic rap', 'sad lo-fi'] 	 44
# 15. clip! 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 39
# 16. i can be your home 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 49
# 17. homescreen 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 38
# 18. pretty sad 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 38
# 19. Good for Nothing 	 ['Powfu', 'guardin'] 	 ['sad rap', 'dark trap', 'emo rap', 'pop rap', 'sad lo-fi'] 	 43
# 20. when things were awkward 	 ['Powfu'] 	 ['sad rap'] 	 50
# 21. thor 	 ['push baby'] 	 ['uk pop'] 	 50
# 22. A Song For Kaytlyn 	 ['Snøw', 'Skinny Atlas'] 	 ['sad lo-fi', 'sad rap', 'emo rap', 'lo-fi chill'] 	 33
# 23. love is dying. 	 ['Snøw', 'cøzybøy', 'Powfu'] 	 ['sad lo-fi', 'sad rap', 'emo rap', 'lo-fi chill'] 	 37
# 24. stick n pokes 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 37
# 25. The Story of the Paper Boy 	 ['Powfu'] 	 ['sad rap'] 	 51
# 26. Long Fights, Short Tempers 	 ['Powfu', 'Imfinenow'] 	 ['sad rap', 'lo-fi chill', 'sad lo-fi'] 	 42
# 27. Feel That Again 	 ['Powfu', 'Happily Sad'] 	 ['sad rap', 'emo rap', 'sad lo-fi'] 	 47
# 28. throw it all away (feat. Jomie) 	 ['Powfu', 'Jomie'] 	 ['sad rap', 'lo-fi chill', 'sad lo-fi'] 	 47
# 29. mi amor 	 ['sadeyes', 'guccihighwaters'] 	 ['emo rap', 'sad lo-fi', 'sad rap', 'dark trap'] 	 41
# 30. Evil Queen 	 ['Snøw', 'Skinny Atlas'] 	 ['sad lo-fi', 'sad rap', 'emo rap', 'lo-fi chill'] 	 31
# 31. Days We Had 	 ['Powfu'] 	 ['sad rap'] 	 53
# 32. I Know You're Not Happy 	 ['Powfu'] 	 ['sad rap'] 	 53
# 33. All Without You 	 ['Laeland', 'Snøw'] 	 ['lo-fi chill', 'sad lo-fi', 'sad rap'] 	 48
# 34. future diary (feat. Jomie & Skinny Atlas) 	 ['Powfu', 'Jomie', 'Skinny Atlas'] 	 ['sad rap', 'lo-fi chill', 'sad lo-fi', 'emo rap'] 	 53
# 35. you're my everything 	 ['sadeyes'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 53
# 36. Different Class, Same Boat 	 ['Powfu'] 	 ['sad rap'] 	 53
# 37. change 	 ['One Hope'] 	 ['sad lo-fi'] 	 44
# 38. Cross My Heart 	 ['Nezzy'] 	 [] 	 44
# 39. Summer Love 	 ['Austin Mahone'] 	 ['dance pop', 'pop', 'post-teen pop', 'viral pop'] 	 44
# 40. Wish I Never Loved You 	 ['Bolshiee'] 	 [] 	 44
# 41. Somebody Else 	 ['D at Sea'] 	 [] 	 44
# 42. Hold on Tighter to Me 	 ['Tedy'] 	 [] 	 44
# 43. If You Wanted It Too 	 ['Jake Scott'] 	 ['alt z', 'indiecoustica', 'neo mellow', 'pop', 'pop rock', 'post-teen pop'] 	 44
# 44. Exes 	 ['Loote'] 	 ['alt z', 'dance pop', 'electropop', 'indie poptimism', 'nyc pop', 'pop', 'pop dance', 'pop edm', 'post-teen pop', 'tropical house'] 	 44
# 45. Call You Mine (Acoustic Piano) 	 ['Ben Woodward'] 	 ['acoustic chill', 'viral pop'] 	 44
# 46. Off My Face 	 ['Justin Bieber'] 	 ['canadian pop', 'pop'] 	 44
# 47. stranger to me 	 ['Zachary Knowles'] 	 ['alt z', 'bedroom soul', 'chill pop', 'chill r&b', 'electropop', 'pop'] 	 44
# 48. Black Dress 	 ['Josh Golden'] 	 ['chill r&b', 'la pop', 'sad rap', 'trap soul'] 	 44
# 49. Another Summer Night Without You 	 ['Alexander 23'] 	 ['alt z', 'pop'] 	 44
# 50. Cigarettes In The Morning 	 ['Snøw', 'Kaxi'] 	 ['sad lo-fi', 'sad rap', 'indian lo-fi'] 	 49
# 51. facetime 	 ['sammy rash'] 	 ['gen z singer-songwriter', 'sad rap'] 	 44
# 52. Sweatshirt 	 ['X Lovers'] 	 ['la pop'] 	 44
# 53. this is bs. 	 ['Skinny Atlas', 'Laeland', 'Snøw'] 	 ['emo rap', 'lo-fi chill', 'sad lo-fi', 'sad rap'] 	 54
# 54. What's The Point? 	 ['Snøw'] 	 ['sad lo-fi', 'sad rap'] 	 34
# 55. thenineteenseventyfive 	 ['push baby'] 	 ['uk pop'] 	 54
# 56. I'm Glad You're Mine 	 ['Airr'] 	 [] 	 43
# 57. make you mine - feat. Snøw, Powfu, Rxseboy 	 ['Fudasca', 'Snøw', 'Rxseboy', 'Powfu'] 	 ['emo rap', 'sad lo-fi', 'sad rap', 'aesthetic rap'] 	 50
# 58. Love Hurts 	 ['Dax'] 	 ['canadian hip hop', 'ottawa rap', 'pop rap', 'social media pop'] 	 45
# 59. I hurt you, I don't deserve you. 	 ['Gion'] 	 [] 	 43
# 60. smile 	 ['eli.'] 	 ['emo rap', 'sad lo-fi'] 	 43
# 61. Hide in Your Blue Eyes 	 ['Thomas Reid', 'Powfu'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 50
# 62. Honest Mistake 	 ['Max Embers'] 	 [] 	 45
# 63. commitment issues 	 ['dempsey hope'] 	 ['modern indie pop'] 	 45
# 64. Sorry 	 ['Matt Haughey'] 	 [] 	 45
# 65. carpool 	 ['Zachary Knowles'] 	 ['alt z', 'bedroom soul', 'chill pop', 'chill r&b', 'electropop', 'pop'] 	 45
# 66. tANGERine 	 ['Collin Selman'] 	 [] 	 45
# 67. Whole 	 ['Jordan Hart'] 	 ['modern indie folk'] 	 45
# 68. where was u? 	 ['blackbear'] 	 ['pop', 'pop rap'] 	 45
# 69. Superstar 	 ['Ryan Caraveo'] 	 ['indie pop rap', 'pop rap', 'sad rap'] 	 43
# 70. Bleach 	 ['Call Me Karizma'] 	 ['alt z', 'minnesota hip hop', 'modern alternative rock', 'modern rock', 'pop rap', 'sad rap', 'social media pop'] 	 43
# 71. Tell Me You Want Me 	 ['Snøw', 'Nuxe'] 	 ['sad lo-fi', 'sad rap', 'lo-fi chill'] 	 38
# 72. every time you wanna see a sunlight 	 ['Wikw'] 	 ['sad rap'] 	 43
# 73. You're The Love Of My Life 	 ['Sam Tompkins'] 	 [] 	 43
# 74. Bottled Up 	 ['Soran'] 	 [] 	 43
# 75. Shivers 	 ['Ed Sheeran'] 	 ['pop', 'uk pop'] 	 43
# 76. Lie About You 	 ['OSTON'] 	 ['alt z'] 	 45
# 77. You're The Love Of My Life 	 ['Sam Tompkins'] 	 [] 	 43
# 78. Not Ready To Go 	 ['HARLOR'] 	 [] 	 45
# 79. caught up 	 ['Keepitinside'] 	 ['chill r&b', 'lo-fi chill'] 	 45
# 80. Love Is Poison 	 ['Ollie'] 	 ['emo rap', 'pop rap', 'sad lo-fi', 'sad rap'] 	 45
# 81. Firewood 	 ['Olympus Mars'] 	 [] 	 43
# 82. i love you but you make me cry 	 ['Elthia'] 	 ['gen z singer-songwriter'] 	 45
# 83. i miss u 	 ['Sammyseven'] 	 [] 	 43
# 84. Breakfast With the Moon 	 ['Powfu'] 	 ['sad rap'] 	 55
# 85. 2 Much 	 ['Justin Bieber'] 	 ['canadian pop', 'pop'] 	 42
# 86. Midnight Thoughts 	 ['SadBoyProlific'] 	 ['emo rap', 'sad lo-fi', 'sad rap'] 	 42
# 87. Lotta Love 	 ['Jack & Jack'] 	 ['dance pop', 'pop', 'post-teen pop', 'social media pop', 'teen pop'] 	 46
# 88. I Just Wanna Die 	 ['DonL66t'] 	 [] 	 46
# 89. sometimes i want 2 die 	 ['blackbear'] 	 ['pop', 'pop rap'] 	 42
# 90. Still 	 ['Chris Lanzon'] 	 ['gen z singer-songwriter'] 	 42
# 91. Something to Cry About 	 ['Alec Chambers'] 	 [] 	 46
# 92. Social Anxiety 	 ['Skye'] 	 [] 	 46
# 93. Other World 	 ['Abudy'] 	 [] 	 42
# 94. ICFTI 	 ['James Gillespie'] 	 ['indie anthem-folk'] 	 42
# 95. rendezvous 	 ['Isaac Dunbar'] 	 ['alt z', 'indie pop', 'modern indie pop', 'social media pop'] 	 42
# 96. stay for long 	 ['SANDRO'] 	 [] 	 42
# 97. Bigger Person 	 ['Ali Gatie'] 	 ['canadian hip hop', 'pop'] 	 46
# 98. Blues 	 ['Olive Amun'] 	 [] 	 42
# 99. STAY CLOSE 	 ['SYML'] 	 ['pop'] 	 46
# 100. Spilled My Coffee (feat. Rxseboy & Jack Cullen) 	 ['Snøw', 'Rxseboy', 'Jack Cullen'] 	 ['sad lo-fi', 'sad rap', 'aesthetic rap'] 	 42

# %%
def playlist_exists(name):
    request = get('https://api.spotify.com/v1/me/playlists', headers=headers).json()

    playlists = list(map(lambda playlist: (playlist['id'], playlist['name']), request['items']))

    for playlist in playlists:
        if playlist[1] == name:
            return playlist[0]
        
    return False

# %%
import json
playlist_name = 'Recent-ish Favorites'
new_id = ""
playlist_id_found = playlist_exists(playlist_name)
if playlist_id_found:
    new_id = playlist_id_found
    
    playlist_tracks = list(map(lambda track: {'uri': track['track']['uri']}, get(f'https://api.spotify.com/v1/playlists/{new_id}/tracks', headers=headers).json()['items']))

    delete_json = delete(f'https://api.spotify.com/v1/playlists/{new_id}/tracks',  headers=headers, data=json.dumps({"tracks": playlist_tracks})).json()
    print(delete_json)
else:
    data = {"name": playlist_name, "description": f"Songs related to your medium term top 5", "public": False}
    playlist_creation = post(f'https://api.spotify.com/v1/users/{USER_ID}/playlists', headers=headers, data=json.dumps(data))
    new_id = playlist_creation.json()['id']
# Out:
# {'snapshot_id': 'NSw0ZGZiMGRiOTQxOTU5NTQ3ZDQ5NGUzYzdiYWE4ZTAwMjExN2RjZDUx'}

# %%
song_uris = ''
for neighbor in neighbors:
    if song_dict[neighbor]["id"] != '':
        song_uris += f',spotify:track:{song_dict[neighbor]["id"]}'
    else:
        continue
song_uris = song_uris[1:]
add_songs_req = post(f'https://api.spotify.com/v1/playlists/{new_id}/tracks?uris={song_uris}', headers=headers, data=json.dumps({}))
add_songs_req.json()
# Out:
# {'snapshot_id': 'NiwxODAyMzkxMjJlMWMzMmJlZTc1Y2UyYmI3ZDIzNjE3OGY3OGZiNTQ3'}
