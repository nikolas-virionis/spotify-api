# %%
from requests import get, post, put
import os
import pandas as pd
from sensitive import *

# %%
auth = f"Bearer {AUTH_TOKEN}"
headers = {"Accept": "application/json",
           "Content-Type": "application/json", "Authorization": auth}

# %%
artists = {}
songs = []


def get_total_song_count():
    playlist_res = get(
        f'https://api.spotify.com/v1/playlists/{PLAYLIST_ID}', headers=headers)
    return playlist_res.json()["tracks"]["total"]


def add_genres(list, genres):
    for genre in genres:
        if genre not in list:
            list.append(genre)

    return list


def get_song_genres(song):
    genres = []
    for artist in song["track"]["artists"]:
        id = artist["id"]
        if id not in artists:
            artist_genres_res = get(
                f'https://api.spotify.com/v1/artists/{id}', headers=headers)
            try:
                artist_genres = artist_genres_res.json()["genres"]
            except Exception:
                print(artist_genres_res.json())
            genres = add_genres(genres, artist_genres)
            artists[artist["name"]] = artist_genres
        else:
            genres = add_genres(genres, artists[id])

    return genres


def song_data(song):
    return song["track"]['id'], song["track"]['name'], song["track"]['popularity'], [artist["name"] for artist in song["track"]["artists"]]

# %%
total_song_count = get_total_song_count()

# %%
all_genres = []
for offset in range(0, total_song_count, 100):
    all_genres_res = get(
        f'https://api.spotify.com/v1/playlists/{PLAYLIST_ID}/tracks?limit=100&offset={offset}', headers=headers)
    for song in all_genres_res.json()["items"]:
        (id, name, popularity, artist), song_genres = song_data(
            song), get_song_genres(song)
        songs.append({"id": id, "name": name, "artists": artist,
                     "popularity": popularity, "genres": song_genres})
        all_genres = add_genres(all_genres, song_genres)

# %%
songs = songs[-total_song_count:]

# %%
playlist = pd.DataFrame(data=songs, columns=[
                        'id', 'name', 'artists', 'popularity', 'genres'])

# %%
playlist
# Out:
#                          id                              name  \
# 0    6Z2pe32hFnUd2x5NgO5KFc  Die For You (feat. Dominic Fike)
# 1    4ZLzoOkj0MPWrTLvooIuaa     Get You The Moon (feat. Snøw)
# 2    4WzhjxvLP95y7AMDy0Atwb                       Out Of Love
# 3    4P1L6AniTDJzANaubzWGYs      I'm Not Enough and I'm Sorry
# 4    3xMTM729pJSwUv55WwWcm2                            change
# ..                      ...                               ...
# 980  0R7Hkh6bkomGA6kB62BW1Z    i love you but you make me cry
# 981  6OVpQb3zarqu0vfQav0Wwx            thenineteenseventyfive
# 982  0dOY7HTtl9OhlouW5ToZNC  I'm Leaving, Sorry For Your Loss
# 983  7byGwLkiIzJdHOZKZMS8nd             Something Super Sweet
# 984  5ARrWiDDRDocvURbemcnCy                Cut My Fingers Off
#
#                            artists  popularity  \
# 0    [Justin Bieber, Dominic Fike]          57
# 1                     [Kina, Snøw]          83
# 2                   [Alessia Cara]          77
# 3                   [Teqkoi, Snøw]          69
# 4                       [One Hope]          44
# ..                             ...         ...
# 980                       [Elthia]          45
# 981                    [push baby]          53
# 982                  [iamnotshane]          49
# 983                  [Rory Webley]          65
# 984               [Ethan Bortnick]          50
#
#                                                 genres
# 0            [canadian pop, pop, alternative pop rock]
# 1                                 [sad lo-fi, sad rap]
# 2    [canadian contemporary r&b, canadian pop, danc...
# 3           [emo rap, lo-fi chill, sad lo-fi, sad rap]
# 4                                          [sad lo-fi]
# ..                                                 ...
# 980                          [gen z singer-songwriter]
# 981                                           [uk pop]
# 982                                                 []
# 983                          [alt z, social media pop]
# 984                                                 []
#
# [985 rows x 5 columns]

# %%
playlist.to_csv('playlist.csv', header=True, index=None)

# %%
all_artists = list(artists.keys())
playlist = pd.read_csv('playlist.csv')
playlist
# Out:
#                          id                              name  \
# 0    6Z2pe32hFnUd2x5NgO5KFc  Die For You (feat. Dominic Fike)
# 1    4ZLzoOkj0MPWrTLvooIuaa     Get You The Moon (feat. Snøw)
# 2    4WzhjxvLP95y7AMDy0Atwb                       Out Of Love
# 3    4P1L6AniTDJzANaubzWGYs      I'm Not Enough and I'm Sorry
# 4    3xMTM729pJSwUv55WwWcm2                            change
# ..                      ...                               ...
# 980  0R7Hkh6bkomGA6kB62BW1Z    i love you but you make me cry
# 981  6OVpQb3zarqu0vfQav0Wwx            thenineteenseventyfive
# 982  0dOY7HTtl9OhlouW5ToZNC  I'm Leaving, Sorry For Your Loss
# 983  7byGwLkiIzJdHOZKZMS8nd             Something Super Sweet
# 984  5ARrWiDDRDocvURbemcnCy                Cut My Fingers Off
#
#                                artists  popularity  \
# 0    ['Justin Bieber', 'Dominic Fike']          57
# 1                     ['Kina', 'Snøw']          83
# 2                     ['Alessia Cara']          77
# 3                   ['Teqkoi', 'Snøw']          69
# 4                         ['One Hope']          44
# ..                                 ...         ...
# 980                         ['Elthia']          45
# 981                      ['push baby']          53
# 982                    ['iamnotshane']          49
# 983                    ['Rory Webley']          65
# 984                 ['Ethan Bortnick']          50
#
#                                                 genres
# 0      ['canadian pop', 'pop', 'alternative pop rock']
# 1                             ['sad lo-fi', 'sad rap']
# 2    ['canadian contemporary r&b', 'canadian pop', ...
# 3    ['emo rap', 'lo-fi chill', 'sad lo-fi', 'sad r...
# 4                                        ['sad lo-fi']
# ..                                                 ...
# 980                        ['gen z singer-songwriter']
# 981                                         ['uk pop']
# 982                                                 []
# 983                      ['alt z', 'social media pop']
# 984                                                 []
#
# [985 rows x 5 columns]

# %%
def genres_indexed(genres: list[str]) -> list[int]:
    indexed = []
    for all_genres_x in all_genres:

        continue_outer = False
        for genre in genres:
            index = all_genres_x == genre
            if index:
                continue_outer = True
                indexed.append(int(True))
                break

        if continue_outer:
            continue

        indexed.append(int(False))

    return indexed


def artists_indexed(artists: list[str]) -> list[int]:
    indexed = []
    for all_artists_x in all_artists:

        continue_outer = False
        for genre in artists:
            index = all_artists_x == genre
            if index:
                continue_outer = True
                indexed.append(int(True))
                break

        if continue_outer:
            continue

        indexed.append(int(False))

    return indexed

# %%
playlist["genres_indexed"] = [genres_indexed(
    eval(playlist["genres"][x])) for x in range(len(playlist["genres"]))]

# %%
playlist.columns = playlist.columns.map(lambda x: x.strip())

# %%
playlist["artists_indexed"] = [artists_indexed(
    eval(playlist["artists"][x])) for x in range(len(playlist["artists"]))]

# %%
playlist.columns
# Out:
# Index(['id', 'name', 'artists', 'popularity', 'genres', 'genres_indexed',
#        'artists_indexed'],
#       dtype='object')

# %% [markdown]
# ## KNN

# %%
def knn_prepared_data(df):
    df = df[['id', 'name', 'genres', 'artists',
             'popularity', 'genres_indexed', 'artists_indexed']]
    list = []
    for index in range(len(df['id'])):
        list.append({'id': df['id'][index], 'name': df['name'][index], 'genres': df['genres'][index], 'artists': df['artists'][index],
                    'popularity': df['popularity'][index], 'genres_indexed': df['genres_indexed'][index], 'artists_indexed': df['artists_indexed'][index]})

    return list

# %%
song_dict = knn_prepared_data(playlist)

# %%
import operator


def getNeighbors(song, K):
    distances = []
    for song_index, song_value in enumerate(song_dict):
        if (song_index != song):
            dist = ComputeDistance(song_dict[song], song_value)
            distances.append((song_index, dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(K):
        neighbors.append(distances[x][0])
    return neighbors

# %%
def list_distance(a, b):
    distance = 0
    for item_a, item_b in list(zip(a, b)):
        distance += 0 if item_a == item_b else 0.2 if (len(a) < 400) else 0.1

    return distance

# %%
def ComputeDistance(a, b):
    genres_distance = list_distance(a['genres_indexed'], b['genres_indexed'])
    artists_distance = list_distance(a['artists_indexed'], b['artists_indexed'])
    popularity_distance = abs(a['popularity'] - b['popularity'])
    
    return genres_distance * 1.3 + artists_distance * 0.2 + popularity_distance * 0.004

# %% [markdown]
# ## Song options
#
# ### Choose one of these to get the 50 closest songs to it

# %%
# Set the song name below
top_5 = get('https://api.spotify.com/v1/me/top/tracks?time_range=medium_term&limit=5', headers=headers).json()
song_name = ''
top_5_names = list(map(lambda song: song['name'],top_5['items']))
for i in top_5_names:
    if i in list(playlist['name']):
        song_name = i
        break

# %%
K = 99
item = playlist[[playlist['name'][x] ==
                 song_name for x in range(len(playlist['name']))]]
index = item.index[0]
neighbors = getNeighbors(index, K)
print(song_dict[index]['name'], song_dict[index]['artists'],
      song_dict[index]['genres'], song_dict[index]['popularity'])
for neighbor, index in zip(neighbors, range(1, K + 1)):
    print(
        f'{index}. {song_dict[neighbor]["name"]} \t {song_dict[neighbor]["artists"]} \t {song_dict[neighbor]["genres"]} \t {song_dict[neighbor]["popularity"]}')
# Out:
# The Story of the Paper Boy ['Powfu'] ['sad rap'] 51
# 1. when things were awkward 	 ['Powfu'] 	 ['sad rap'] 	 50
# 2. Different Class, Same Boat 	 ['Powfu'] 	 ['sad rap'] 	 53
# 3. Days We Had 	 ['Powfu'] 	 ['sad rap'] 	 54
# 4. I Know You're Not Happy 	 ['Powfu'] 	 ['sad rap'] 	 54
# 5. Her Ocean Eyes 	 ['Powfu'] 	 ['sad rap'] 	 48
# 6. Breakfast With the Moon 	 ['Powfu'] 	 ['sad rap'] 	 55
# 7. clash of the titans 	 ['Powfu'] 	 ['sad rap'] 	 46
# 8. Hear my thoughts 	 ['Powfu'] 	 ['sad rap'] 	 56
# 9. no promises (feat. Scapegoat) 	 ['Powfu', 'Scapegoat'] 	 ['sad rap'] 	 55
# 10. Douchebags 	 ['Powfu'] 	 ['sad rap'] 	 41
# 11. Haunted 	 ['Zimm'] 	 ['sad rap'] 	 51
# 12. im used to it 	 ['Powfu'] 	 ['sad rap'] 	 62
# 13. step into my life 	 ['Powfu', 'sleep.ing'] 	 ['sad rap'] 	 59
# 14. the fire in your eyes keeps me warm 	 ['Powfu', 'sleep.ing', 'Arvnd'] 	 ['sad rap'] 	 55
# 15. every time you wanna see a sunlight 	 ['Wikw'] 	 ['sad rap'] 	 44
# 16. i heard heaven is a nice place 	 ['Carter Powers'] 	 ['sad rap'] 	 40
# 17. ESSAY 	 ['Kodoku', 'Darius King'] 	 ['sad rap'] 	 42
# 18. Come Alive 	 ['ill Nicky'] 	 ['sad rap'] 	 33
# 19. Warzone 	 ['Bri-C', 'Monty Xon'] 	 ['sad rap'] 	 37
# 20. After Hours 	 ['charlieonnafriday'] 	 ['sad rap'] 	 71
# 21. CRY IT OUT 	 ['Adam Oh', 'Kish'] 	 ['sad rap'] 	 31
# 22. Don't Save Me 	 ['ill Nicky'] 	 ['sad rap'] 	 23
# 23. headaches 	 ['Zac Greer'] 	 ['sad rap'] 	 2
# 24. stay4ever (feat. Mounika.) 	 ['Powfu', 'Mounika.'] 	 ['sad rap', 'chillhop'] 	 56
# 25. Unlove 	 ['Lyle Kam'] 	 [] 	 51
# 26. as long as i have you 	 ['Foster'] 	 ['sad lo-fi', 'sad rap'] 	 51
# 27. Dim the Lights 	 ['Ricky Rosen'] 	 [] 	 51
# 28. Hell and Back 	 ['Paradoxx'] 	 ['emo rap', 'sad rap'] 	 50
# 29. come home 	 ['lilspirit'] 	 [] 	 50
# 30. Switchblade 	 ['neverwaves'] 	 [] 	 50
# 31. Cut My Fingers Off 	 ['Ethan Bortnick'] 	 [] 	 50
# 32. I Hate You, But I Love You 	 ['Lil Yung Pharaoh'] 	 ['emo rap', 'sad rap'] 	 53
# 33. Hate You 	 ['Seann Bowe'] 	 [] 	 53
# 34. Tired 	 ['Anke Richards'] 	 [] 	 49
# 35. Honey 	 ['Nathan Benjamin'] 	 [] 	 49
# 36. Copenhagen 	 ['Jack Vallier'] 	 [] 	 49
# 37. im all alone 	 ['lael'] 	 [] 	 49
# 38. Out of Love 	 ['Peter Manos'] 	 [] 	 53
# 39. can't give back your love 	 ['clide'] 	 [] 	 49
# 40. Romeo 	 ['Bryce Xavier'] 	 [] 	 53
# 41. I'm Leaving, Sorry For Your Loss 	 ['iamnotshane'] 	 [] 	 49
# 42. Hopefully Someday 	 ['YouSane'] 	 [] 	 48
# 43. Golden Eyes 	 ['HANNI'] 	 [] 	 48
# 44. Earth Boy 	 ['Tony22'] 	 [] 	 54
# 45. Who Are You? / PLAYBOY BUNNY 	 ['Wario Slim'] 	 [] 	 48
# 46. all figured out 	 ['44phantom'] 	 ['emo rap', 'sad rap'] 	 47
# 47. I Just Wanna Die 	 ['DonL66t'] 	 [] 	 47
# 48. Just Hold On 	 ['Presence'] 	 ['sad lo-fi', 'sad rap'] 	 55
# 49. tell me when you change 	 ['Jay Sek', 'Powfu', 'Tidal Francis'] 	 ['emo rap', 'sad rap'] 	 47
# 50. I keep on falling 	 ['Gabriella Whited'] 	 [] 	 47
# 51. Charlie 	 ['Sam Tompkins'] 	 [] 	 47
# 52. Something to Cry About 	 ['Alec Chambers'] 	 [] 	 46
# 53. broken parts 	 ['clide'] 	 [] 	 56
# 54. Social Anxiety 	 ['Skye'] 	 [] 	 46
# 55. Honest Mistake 	 ['Max Embers'] 	 [] 	 46
# 56. I'm Okay Now 	 ['badly'] 	 [] 	 56
# 57. INSPIRED 	 ['NEFFEX'] 	 [] 	 56
# 58. Bloodline 	 ['Sam Tompkins'] 	 [] 	 56
# 59. Tell Me 	 ['Era', 'lilspirit'] 	 [] 	 52
# 60. Cross My Heart 	 ['Nezzy'] 	 [] 	 45
# 61. Somebody Else 	 ['D at Sea'] 	 [] 	 45
# 62. Sorry 	 ['Matt Haughey'] 	 [] 	 45
# 63. facetime 	 ['sammy rash'] 	 ['gen z singer-songwriter', 'sad rap'] 	 45
# 64. Not Ready To Go 	 ['HARLOR'] 	 [] 	 45
# 65. Wish I Never Loved You 	 ['Bolshiee'] 	 [] 	 44
# 66. Hold on Tighter to Me 	 ['Tedy'] 	 [] 	 44
# 67. tANGERine 	 ['Collin Selman'] 	 [] 	 44
# 68. Firewood 	 ['Olympus Mars'] 	 [] 	 44
# 69. Suicide Letter 2 	 ['Trick James'] 	 ['iowa hip hop', 'sad rap'] 	 59
# 70. I'm Glad You're Mine 	 ['Airr'] 	 [] 	 43
# 71. Crying My Eyes Out 	 ['Stephen Puth'] 	 [] 	 59
# 72. I hurt you, I don't deserve you. 	 ['Gion'] 	 [] 	 43
# 73. stay for long 	 ['SANDRO'] 	 [] 	 43
# 74. I'm So Happy 	 ['Monica Riskey'] 	 [] 	 43
# 75. You're The Love Of My Life 	 ['Sam Tompkins'] 	 [] 	 43
# 76. Unspoken 	 ['Austin Andrea'] 	 [] 	 43
# 77. On My Own 	 ['Shane Moyer'] 	 [] 	 43
# 78. You're The Love Of My Life 	 ['Sam Tompkins'] 	 [] 	 43
# 79. Other World 	 ['Abudy'] 	 [] 	 42
# 80. Blues 	 ['Olive Amun'] 	 [] 	 42
# 81. Whole 	 ['Sam Tompkins'] 	 [] 	 60
# 82. Love Letter III 	 ['7ru7h'] 	 ['emo rap', 'sad rap'] 	 42
# 83. Life with You (Powfu) 	 ['Mixed Version'] 	 [] 	 41
# 84. Dear Diary 	 ['Mikelwj'] 	 [] 	 41
# 85. Down Bad 	 ['Erin Kaith'] 	 [] 	 61
# 86. You Are Not Charles Bukowski 	 ['Harry Jay Robinson'] 	 [] 	 41
# 87. Bottled Up 	 ['Soran'] 	 [] 	 41
# 88. Cinema - Acoustic 	 ['Gary Go'] 	 [] 	 62
# 89. If You Leave 	 ['Sky McCreery'] 	 ['sad lo-fi', 'sad rap'] 	 62
# 90. aftermath 	 ['vaultboy'] 	 [] 	 62
# 91. You Are the One 	 ['Airr'] 	 [] 	 39
# 92. Stop Myself 	 ['Soran'] 	 [] 	 39
# 93. 26 	 ['Kid Indigo'] 	 [] 	 39
# 94. new jersey 	 ['.irg'] 	 [] 	 39
# 95. bad timing 	 ['Darko'] 	 ['emo rap', 'sad rap'] 	 39
# 96. stand ten feet away from me 	 ['Sam Tompkins'] 	 [] 	 39
# 97. Crazy in Love 	 ['Eden Project'] 	 [] 	 63
# 98. lunar light 	 ['Mikey Ferrari'] 	 [] 	 39
# 99. Sad Together 	 ['Hayk Keys'] 	 [] 	 38

# %%
import json
data = {"name": f"Recent-ish Favorites", "description": f"Songs related to your medium term top 5", "public": False}
playlist_creation = post(f'https://api.spotify.com/v1/users/{USER_ID}/playlists', headers=headers, data=json.dumps(data))
new_id = playlist_creation.json()['id']

# %%
item = playlist[[playlist['name'][x] ==
                 song_name for x in range(len(playlist['name']))]]
index = item.index[0]
song_uris = f'spotify:track:{song_dict[index]["id"]}'
for neighbor in neighbors:
    song_uris += f',spotify:track:{song_dict[neighbor]["id"]}'

add_songs_req = post(f'https://api.spotify.com/v1/playlists/{new_id}/tracks?uris={song_uris}', headers=headers, data=json.dumps({}))
add_songs_req.json()
# Out:
# {'snapshot_id': 'MyxlN2NiNWViY2NjMWYyMTUzMzIwYjZkOTcwYWE5ZWRhZjMzNWYxZTIz'}
